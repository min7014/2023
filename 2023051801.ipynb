# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2023/blob/main/2023051801.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [분산, 표준편차 구하기(Finding The Variance And Standard Deviation)](https://min7014.github.io/math20210308001.html)

# %% [markdown]
# ### [참고]
#
# [Geogebra와 수학의 시각화](https://www.geogebra.org/m/gsARCQs5)

# %% [markdown]
# **[영문버전]**

# %% [markdown]
# https://www.geogebra.org/m/qhbmhpwe

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 01. Geogebra를 실행시킨다.
#
# 02. 대수창에  오른쪽 방향 선택하면 아래방향으로 바뀌면서 추가메뉴가 나오고
#
#     **첫번째 아래방향 --> Sort by --> Construction order**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 03. Input에
#
#     **Data1={9,7,6,6,9,5,7,6,7,8}**
#
#     입력하여 Data1라는 list를 만든다.
#
#
#
# 04. Input에
#
#     **Data2={6,7,7,6,8,7,7,7,7,8}**
#
#     입력하여 Data2라는 list를 만든다.
#
#
#
# 05. 대수창과 기하창 경계에 마우스를 위치시켰을때 마우스 커서가 좌우화살표로 변한다.
#
#     이때 왼쪽 마우스를 누른상태로 대수창을 넓혀서 Data1과 Data2의 내용이 다 보이도록 창의 너비를 조절한다.
#
#
#
# 06. Input에
#
#     **NumberOfD1=CountIf[x==x,Data1]**
#
#     입력하여 NumberOfD1라는 수를 만든다.
#
#
#
# 07. Input에
#
#     **NumberOfD2=CountIf[x==x,Data2]**
#
#     입력하여 NumberOfD2라는 수를 만든다.
#
#
#
# 08. Input에
#
#     **SumOfD1=Sum[Data1]**
#
#     입력하여 SumOfD1이라는 수를 만든다.
#
#
#
# 09. Input에
#
#     **SumOfD2=Sum[Data2]**
#
#     입력하여 SumOfD2이라는 수를 만든다.
#
#
#
# 10. Input에
#
#     **AverageOfD1=SumOfD1/NumberOfD1**
#
#     입력하여 AverageOfD1이라는 수를 만든다.
#
#
#
# 11. Input에
#
#     **AverageOfD2=SumOfD2/NumberOfD2**
#
#     입력하여 AverageOfD2이라는 수를 만든다.
#
#
#
# 12. Input에
#
#     **DeviationOfD1=Sequence[Element[Data1,t]-AverageOfD1,t,1,NumberOfD1]**
#
#     입력하여 DeviationOfD1라는 list를 만든다.
#
#
#
# 13. Input에
#
#     **DeviationOfD2=Sequence[Element[Data2,t]-AverageOfD2,t,1,NumberOfD2]**
#
#     입력하여 DeviationOfD2라는 list를 만든다.
#
#
#
# 14. Input에
#
#     **SumOfDD1=Sum[DeviationOfD1]**
#
#     입력하여 SumOfDD1이라는 수를 만든다.
#
#
#
# 15. Input에
#
#     **SumOfDD2=Sum[DeviationOfD2]**
#
#     입력하여 SumOfDD2이라는 수를 만든다.
#     SumOfDD1과 SumOfDD2이 0의 값을 가지는 이유를 생각해봅니다.
#     항상 0이므로 산포도로 사용할 수 없음을 생각합니다.
#
#
#
# 16. Input에
#
#     **SquaredDD1=Sequence[(Element[Data1,t]-AverageOfD1)^2,t,1,NumberOfD1]**
#
#     입력하여 SquaredDD1이라는 list를 만든다.
#
#
#
# 17. Input에
#
#     **SquaredDD2=Sequence[(Element[Data2,t]-AverageOfD2)^2,t,1,NumberOfD2]**
#
#     입력하여 SquaredDD2이라는 list를 만든다.
#
#
#
# 18. Input에
#
#     **SumOfSDD1=Sum[SquaredDD1]**
#
#     입력하여 SumOfSDD1이라는 수를 만든다.
#
#
#
# 19. Input에
#
#     **SumOfSDD2=Sum[SquaredDD2]**
#
#     입력하여 SumOfSDD2이라는 수를 만든다.
#
#
#
# 20. Input에
#
#     **DistributionOfD1=SumOfSDD1/NumberOfD1**
#
#     입력하여 DistributionOfD1이라는 수를 만든다.
#
#
#
# 21. Input에
#
#     **DistributionOfD2=SumOfSDD2/NumberOfD2**
#
#     입력하여 DistributionOfD2이라는 수를 만든다.
#
#
#
# 22. Input에
#
#     **StandardDeviationD1=DistributionOfD1^0.5**
#
#     입력하여 StandardDeviationD1라는 수를 만든다.
#
#
#
# 23. Input에
#
#     **StandardDeviationD2=DistributionOfD2^0.5**
#
#     입력하여 StandardDeviationD2라는 수를 만든다.
#
#
#
# 24. Geogebra 상단에 File, Edit, View, Options, Tools, Window, Help에서
#
#    **Options --> Rounding --> 15 Decimal Places**
#
#   소수점15자리까지 보였지만, 분산의 값은 근사값일 뿐입니다.
#
#   Geogebra에는 심볼릭계산이 가능한 기능이 있습니다.
#
#   심볼릭계산으로 정확한 값을 볼 수 있습니다.
#
#
#
# 25. Geogebra 상단에 File, Edit, View, Options, Tools, Window, Help에
#
#    **View  --> CAS**
#
# 　 선택합니다.
#
# 26. Cas의 1이란 수 옆의 빈칸에
#
#     **stdevp[Data1]**
#
#     입력하여 계산결과 확인합니다.
#
#
#
# 27. Cas에
#
#     **stdevp[Data2]**
#
#     입력하여 계산결과 확인합니다.
#
#
#
# 28. Input에
#
#     **GeogebraVarianceFunctionAppliedToData1=Variance[Data1]**
#
#     입력하여 GeogebraVarianceFunctionAppliedToData1라는 수를 만든다.
#
# 29. Input에
#
#     **GeogebraVarianceFunctionAppliedToData2=Variance[Data2]**
#
#     입력하여 GeogebraVarianceFunctionAppliedToData2라는 수를 만든다.
#
#
#
# 30. Input에
#
#     **GeogebraStandardDeviationFunctionAppliedToData1=stdevp[Data1]**
#
#     입력하여 GeogebraStandardDeviationFunctionAppliedToData1라는 수를 만든다.
#
#
# 31. Input에
#
#     **GeogebraStandardDeviationFunctionAppliedToData2=stdevp[Data2]**
#
#     입력하여 GeogebraStandardDeviationFunctionAppliedToData2라는 수를 만든다.
#
#
#
# 32. Goegebra에도 분산과 표준편차 함수가 있다. 하지만, 과정이 중요하므로 위와 같이 작성함.

# %% [markdown]
# **[한글버전]**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 01. Geogebra를 실행시킨다.
#
#
#
# 02. 대수창에  오른쪽 방향 선택하면 아래방향으로 바뀌면서 추가메뉴가 나오고
#
#     첫번째 아래방향을 선택 --> 정렬기준 --> 구성순서를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 03. 입력창에
#
#     **자료1={9,7,6,6,9,5,7,6,7,8}**
#
#     입력하여 자료1라는 리스트를 만든다.
#
#
#
# 04. 입력창에
#
#     **자료2={6,7,7,6,8,7,7,7,7,8}**
#
#     입력하여 자료2라는 리스트를 만든다.
#
#
#
# 05. 대수창과 기하창 경계에 마우스를 위치시켰을때 마우스 커서가 좌우화살표로 변한다.
#
#     이때 왼쪽 마우스를 누른상태로 대수창을 넓혀서 자료1과 자료2의 내용이
#
#     다 보이도록 창의 너비를 조절한다.
#
#
#
# 06. 입력창에
#
#     **자료1개수=세기조건[x==x,자료1]**
#
#     입력하여 자료1개수라는 수를 만든다.
#
#
#
# 07. 입력창에
#
#     **자료2개수=세기조건[x==x,자료2]**
#
#     입력하여 자료2개수라는 수를 만든다.
#
#
#
# 08. 입력창에
#
#     **자료1합=합[자료1]**
#
#     입력하여 자료1합이라는 수를 만든다.
#
#
#
# 09. 입력창에
#
#     **자료2합=합[자료2]**
#
#     입력하여 자료2합이라는 수를 만든다.
#
#
#
# 10. 입력창에
#
#     **자료1평균=자료1합/자료1개수**
#
#     입력하여 자료1평균이라는 수를 만든다.
#
#
#
# 11. 입력창에
#
#     **자료2평균=자료2합/자료2개수**
#
#     입력하여 자료2평균이라는 수를 만든다.
#
#
#
# 12. 입력창에
#
#     **자료1편차=수열[원소[자료1,t]-자료1평균,t,1,자료1개수]**
#
#     입력하여 자료1편차라는 리스트를 만든다.
#
#
#
# 13. 입력창에
#
#     **자료2편차=수열[원소[자료2,t]-자료2평균,t,1,자료2개수]**
#
#     입력하여 자료2편차라는 리스트를 만든다.
#
#
#
# 14. 입력창에
#
#     **자료1편차합=합[자료1편차]**
#
#     입력하여 자료1편차합이라는 수를 만든다.
#
#
#
# 15. 입력창에
#
#     **자료2편차합=합[자료2편차]**
#
#     입력하여 자료2편차합이라는 수를 만든다.
#
#
#
# 자료1편차합과 자료2편차합이 0의 값을 가지는 이유를 생각해봅니다.
#
# 항상 0이므로 산포도로 사용할 수 없음을 생각합니다.
#
#
#
# 16. 입력창에
#
#     **자료1편차제곱=수열[(원소[자료1,t]-자료1평균)^2,t,1,자료1개수]**
#
#     입력하여 자료1편차제곱이라는 리스트를 만든다.
#
#
#
# 17. 입력창에
#
#     **자료2편차제곱=수열[(원소[자료2,t]-자료2평균)^2,t,1,자료2개수]**
#
#     입력하여 자료2편차제곱이라는 리스트를 만든다.
#
#
#
# 18. 입력창에
#
#     **자료1편차제곱합=합[자료1편차제곱]**
#
#     입력하여 자료1편차제곱합이라는 수를 만든다.
#
#
#
# 19. 입력창에
#
#     **자료2편차제곱합=합[자료2편차제곱]**
#
#     입력하여 자료2편차제곱합이라는 수를 만든다.
#
#
#
# 20. 입력창에
#
#     **자료1의분산=자료1편차제곱합/자료1개수**
#
#     입력하여 자료1의분산이라는 수를 만든다.
#
#
#
# 21. 입력창에
#
#     **자료2의분산=자료2편차제곱합/자료2개수**
#
#     입력하여 자료2의분산이라는 수를 만든다.
#
#
#
# 22. 입력창에
#
#     **자료1의표준편차=자료1의분산^0.5**
#
#     입력하여 자료1의표준편차라는 수를 만든다.
#
#
#
# 23. 입력창에
#
#     **자료2의표준편차=자료2의분산^0.5**
#
#     입력하여 자료2의표준편차라는 수를 만든다.
#
#
#
# 24. Geogebra 상단에 파일, 편집, 보기, 선택사항, 도구, 원도우, 도움말에서
#
#    **선택사항 --> 반올림 --> 15 소수점 아래 자리 선택**
#
#   소수점15자리까지 보였지만, 분산의 값은 근사값일 뿐입니다.
#
#   Geogebra에는 심볼릭계산이 가능한 기능이 있습니다.
#
#   심볼릭계산으로 정확한 값을 볼 수 있습니다.
#
#
#
# 25. Geogebra 상단에 파일, 편집, 보기, 선택사항, 도구, 원도우, 도움말에
#
#    **보기  --> CAS 선택 하여 CAS 창을 보이게 합니다.**
#
#
#
# 26. Cas 창의 1이란 수 옆의 빈칸에
#
#     **표준편차[자료1]**
#
#     입력하여 계산결과 확인합니다.
#
#
#
# 27. Cas 창에
#
#     **표준편차[자료2]**
#
#     입력하여 계산결과 확인합니다.
#
#
#
# 28. 입력창에
#
#     **Geogebra분산함수자료1=분산[자료1]**
#
#     입력하여 자료2의표준편차라는 수를 만든다.
#
#
#
#
#
# 29. 입력창에
#
#     **Geogebra분산함수자료2=분산[자료2]**
#
#     입력하여 자료2의표준편차라는 수를 만든다.
#
#
#
# 30. 입력창에
#
#     **Geogebra표준편차함수자료1=표준편차[자료1]**
#
#     입력하여 자료2의표준편차라는 수를 만든다.
#
#
# 31. 입력창에
#
#     **Geogebra표준편차함수자료2=표준편차[자료2]**
#
#     입력하여 자료2의표준편차라는 수를 만든다.
#
#
#
# 32. Goegebra에도 분산과 표준편차 함수가 있다. 하지만, 과정이 중요하므로 위와 같이 작성함.
