# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2023/blob/main/2023120302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **작도와 경사하강법을 활용한 삼각형의 페르마 점에 대한 접근(민은기)(2023.12.20)**

# %% [markdown]
# ![profile.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 삼각형의 페르마 점(Fermat point)는 삼각형의 세 꼭짓점에서 거리의 합이 최소가 되는 점을 말한다. 이를 두 가지 시각에서 접근하려고 한다. 하나의 시각은 작도를 활용하여 페르마 점을 작도하는 방법이다. 다른 시각은 인공지능에 쓰이는 경사하강법을 활용하여 페르마 점에 다가가는 방법이다. 이 두 가지를 수학공학도구인 Geogebra를 활용하여 만들어 보겠다.

# %% [markdown]
# # 작도를 활용한 페르마 점에 대한 접근

# %% [markdown]
# Geogebra를 실행시킨다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Option]을 선택하고 [Font Size]를 선택한 다음, [24pt]를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Graphics]에서 마우스 오른쪽 버튼을 누르고 [Axes]를 선택하여 Axes를 보이지 않게 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Graphics]에서 마우스 오른쪽 버튼을 누르고 [Grid]를 선택하여 Grid를 보이지 않게 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Point] 도구를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Graphics] 창에 마우스를 클릭하여 세 점을 만든다. 차례대로 $\rm{A}$, $\rm{B}$, $\rm{C}$의 이름이 붙여진다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 점 $\rm{A}$를 선택하고 오른쪽 마우스를 누르고, [Object Properties]를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Properties] 창이 나타난다. 하지만, [Graphics] 창이 좁아진다. [Properties] 창의 닫기 버튼(x 모양) 근처에 가면 [Graphics] 창을 따로 띄울 수 있는 버튼이 나타난다. 이 버튼을 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Proferences] 창이 새로 나타났다. [Caption]에 \$\mathrm{A}\$ 를 입력한다. \$ 수식 \$ 형식으로 LaTex을 사용할 수 있다. [Show Label] 에 아래쪽 걱쇠를 선택하고 [Caption]을 선택한다. $\rm{A}$ 가 수학 책에서 보아왔던 점 이름 형태로 보인다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 점 $\rm{B}$, 점 $\rm{C}$에 각각  \$\mathrm{B}\$,  \$\mathrm{C}\$ 를 입력하여 마찮가지 방식으로 수학 책에서 보아왔던 형태로 바꿔준다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Move] 도구를 선택한다. 점 $\rm{A}$, 점 $\rm{B}$, 점 $\rm{C}$를 원하는 위치로 이동시킬 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [View]를 선택하고 [Graphics 2]를 선택하여 [Graphics 2]가 나타나도록 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Geogebra의 창의 모서리를 선택하여 보기 좋게 크기를 조절한다. 또한, [Move Graphics View] 도구를 선택하고 [Graphics] 창의 중간에(x자 표시) 마우스의 왼쪽 버튼을 누른 상태에서 드래그 해서 [Graphics] 창에 있는 모든 기하적 대상이 전제적으로 보기좋게 위치시켜 놓는다. [Graphics]에서 Axes와 Grid를 보이지 않게 했던 방식으로 [Graphics 2] 창의 Axes를 보이지 않게 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Check Box] 도구를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Ctrl]를 누른상태에서 기하적 대상을 선태하면 한번에 선택가능하다. [Ctrl]를 누른 상태에서 점 $\rm{A}$, 점 $\rm{B}$, 점 $\rm{C}$를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Graphics 2] 창에 x표시한 위치를 마우스로 선택하면, [Check Box to Show/Hide Objects] 창이 나타난다. [Caption]에 1을 입력하고 [Apply]버튼을 누르면,  [Graphics 2] 창에 Check Box 1이 나타난다. Check Box 1의 실제 객체 이름은 a이고 체크된 상태의 논리값이 true로 되어 있음을 확인 할 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Move] 도구를 선택한 상태에서, [Graphics 2] 창의 Check Box 1를 체크 해제한다. [Grpahics] 창의 점들이 안보이게 된다. 다시 체크 하면 보여진다. [Check Box] 도구를 사용하면 만들어지는 대상들을 순서에 맞추어 보이고 보이지 않게 할 수 있다. 수학은 논리적인 과정이 중요하다. 따라서 수학에서 [Check Box]는 아주 유용한 도구가 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Point] 도구를 선택한 후, [Graphics] 창을 선택한다. 점 $\rm{D}$가 만들어 진다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 점 $\rm{D}$에서 오른쪽 마우스를 누르고 [Object Properties]를 선택하여, [Preferences] 창이 나타나도록 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
