# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2023/blob/main/2023120302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **[치악고등학교]작도와 경사하강법을 활용한 삼각형의 페르마 점에 대한 접근(민은기)(2023.12.20)**

# %% [markdown]
# ![profile.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 삼각형의 페르마 점(Fermat point)는 삼각형의 세 꼭짓점에서 거리의 합이 최소가 되는 점을 말한다. 이를 두 가지 시각에서 접근하려고 한다. 일단 작도를 활용할 수 있겠다. 다른 시각은 인공지능에 쓰이는 경사하강법이다. 이 두 가지를 수학공학도구인 Geogebra를 활용하여 보이려고 한다.

# %% [markdown]
# Geogebra를 실행시켜 경사하강법이다. 이 두 가지를 수학공학도구인 Geogebra를 활용하여 접근해 보겠다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Geogebra를 실행시킨다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Font Size]를 [24pt]로 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Graphics]에서 마우스 오른쪽 버튼을 누르고 [Axes]를 선택하여 Axes를 보이지 않게 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Graphics]에서 마우스 오른쪽 버튼을 누르고 [Grid]를 선택하여 Grid를 보이지 않게 한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Point] 도구를 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [Graphics] 창에 마우스를 클릭하여 세 점을 만든다. 차례대로 A, B, C의 이름이 붙여진다.
